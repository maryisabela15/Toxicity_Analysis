# %%
import pandas as pd

df = pd.read_csv("cleaned_comments.csv")

# %%
# Keep only the first 250 rows
df = df.head(250)

# Convert to Label Studio-compatible JSON format
data = [{'data': {'text': row['text']}} for index, row in df.iterrows()]

# Save to a new JSON file
with open('subset_250.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

print("✅ Done! 'subset_250.json' created with 250 entries.")
# Out:
# ✅ Saved as cleaned_comments.jsonl – ready for Label Studio
